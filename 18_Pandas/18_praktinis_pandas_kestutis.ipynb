# %%
import pandas as pd
import numpy as np
# Out:
# /var/folders/n6/nzyv9f853k7djbyfmdph5t5w0000gn/T/ipykernel_12567/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## pirma dalis
# ---

# %%
labels = ('vardas', 'pavardė', 'amžius')
zmogus = ('Geras', 'Zmogelis', 33)
print(labels, zmogus)
# Out:
# ('vardas', 'pavardė', 'amžius') ('Geras', 'Zmogelis', 33)

# %%
pd.Series(data=zmogus)
# Out:
# 0       Geras
# 1    Zmogelis
# 2          33
# dtype: object

# %%
pd.Series(data=zmogus, index=labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_dict = {
    'vardas': 'Smagus',
    'pavarde': 'Giedriukas',
    'amzius': 36
}
zmogus_dict
# Out:
# {'vardas': 'Smagus', 'pavarde': 'Giedriukas', 'amzius': 36}

# %%
zmogus_pd = pd.Series(zmogus_dict)
zmogus_pd
# Out:
# vardas         Smagus
# pavarde    Giedriukas
# amzius             36
# dtype: object

# %%
pd.Series(zmogus, labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_pd['amzius']
# Out:
# 36

# %%
miestai = pd.Series((500, 400, 300, 200), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
miestai
# Out:
# Vilnius     500
# Kaunas      400
# Klaipeda    300
# Siauliai    200
# dtype: int64

# %%
augimas = pd.Series((1.5, 1.3, 0.9, 0.7), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
augimas
# Out:
# Vilnius     1.5
# Kaunas      1.3
# Klaipeda    0.9
# Siauliai    0.7
# dtype: float64

# %%
miestai * augimas
# Out:
# Vilnius     750.0
# Kaunas      520.0
# Klaipeda    270.0
# Siauliai    140.0
# dtype: float64

# %%
betko7x7 = np.random.randint(10, 100, (7, 7))
betko7x7
# Out:
# array([[58, 91, 74, 97, 24, 59, 93],
#        [38, 18, 73, 22, 35, 11, 71],
#        [82, 48, 39, 80, 32, 86, 59],
#        [59, 91, 44, 42, 74, 76, 49],
#        [53, 13, 65, 69, 71, 57, 88],
#        [91, 44, 79, 17, 67, 64, 62],
#        [96, 21, 12, 54, 70, 75, 18]])

# %%
miestu_skaiciai = pd.DataFrame(
    betko7x7,
    [2000, 2004, 2008, 2012, 2016, 2020, 2024],
    ['Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai', 'Panevezys', 'Alytus', 'Druskininkai']
)
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai
# 2000       58      91        74        97         24      59            93
# 2004       38      18        73        22         35      11            71
# 2008       82      48        39        80         32      86            59
# 2012       59      91        44        42         74      76            49
# 2016       53      13        65        69         71      57            88
# 2020       91      44        79        17         67      64            62
# 2024       96      21        12        54         70      75            18

# %%
miestu_skaiciai['Klaipeda']
# Out:
# 2000    74
# 2004    73
# 2008    39
# 2012    44
# 2016    65
# 2020    79
# 2024    12
# Name: Klaipeda, dtype: int64

# %%
print(type(miestu_skaiciai['Klaipeda']))
print(type(miestu_skaiciai))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
miestu_skaiciai[['Vilnius', 'Alytus', 'Druskininkai']]
# Out:
#       Vilnius  Alytus  Druskininkai
# 2000       58      59            93
# 2004       38      11            71
# 2008       82      86            59
# 2012       59      76            49
# 2016       53      57            88
# 2020       91      64            62
# 2024       96      75            18

# %%
miestu_skaiciai['Vilnius'][2000] = 99
miestu_skaiciai['Vilnius'][2000]
# Out:
# /var/folders/n6/nzyv9f853k7djbyfmdph5t5w0000gn/T/ipykernel_12567/2762690240.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   miestu_skaiciai['Vilnius'][2000] = 99
# 99

# %%
miestu_skaiciai.loc[2012]
# Out:
# Vilnius         59
# Kaunas          91
# Klaipeda        44
# Siauliai        42
# Panevezys       74
# Alytus          76
# Druskininkai    49
# Name: 2012, dtype: int64

# %%
kazluruda = pd.Series(np.random.randint(10, 99, 7), np.arange(2000, 2025, 4))
kazluruda
# Out:
# 2000    16
# 2004    21
# 2008    93
# 2012    82
# 2016    90
# 2020    11
# 2024    21
# dtype: int64

# %%
miestu_skaiciai['Kazlu Ruda'] = kazluruda
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai  \
# 2000       99      91        74        97         24      59            93
# 2004       38      18        73        22         35      11            71
# 2008       82      48        39        80         32      86            59
# 2012       59      91        44        42         74      76            49
# 2016       53      13        65        69         71      57            88
# 2020       91      44        79        17         67      64            62
# 2024       96      21        12        54         70      75            18
#
#       Kazlu Ruda
# 2000          16
# 2004          21
# 2008          93
# 2012          82
# 2016          90
# 2020          11
# 2024          21

# %%
miestu_skaiciai.drop('Siauliai', axis=1, inplace=True)

# %%
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      91        74         24      59            93          16
# 2004       38      18        73         35      11            71          21
# 2008       82      48        39         32      86            59          93
# 2012       59      91        44         74      76            49          82
# 2016       53      13        65         71      57            88          90
# 2020       91      44        79         67      64            62          11
# 2024       96      21        12         70      75            18          21

# %%
miestai_be_2008 = miestu_skaiciai.drop(2008)
miestai_be_2008
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      91        74         24      59            93          16
# 2004       38      18        73         35      11            71          21
# 2012       59      91        44         74      76            49          82
# 2016       53      13        65         71      57            88          90
# 2020       91      44        79         67      64            62          11
# 2024       96      21        12         70      75            18          21

# %%
miestu_skaiciai.loc[2008]
# Out:
# Vilnius         82
# Kaunas          48
# Klaipeda        39
# Panevezys       32
# Alytus          86
# Druskininkai    59
# Kazlu Ruda      93
# Name: 2008, dtype: int64

# %%
miestu_skaiciai.iloc[3]
# Out:
# Vilnius         59
# Kaunas          91
# Klaipeda        44
# Panevezys       74
# Alytus          76
# Druskininkai    49
# Kazlu Ruda      82
# Name: 2012, dtype: int64

# %%
miestu_skaiciai['Vilnius'][2020]
# Out:
# 91

# %%
miestu_skaiciai.loc[2020, 'Vilnius']
# Out:
# 91

# %%
miestu_skaiciai.loc[[2012, 2020, 2024], ['Kaunas', 'Alytus']]
# Out:
#       Kaunas  Alytus
# 2012      91      76
# 2020      44      64
# 2024      21      75

# %%
miestu_skaiciai[['Kaunas', 'Alytus']].loc[[2020, 2012, 2000]]
# Out:
#       Kaunas  Alytus
# 2020      44      64
# 2012      91      76
# 2000      91      59

# %%
miestu_skaiciai[miestu_skaiciai > 70]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000     99.0    91.0      74.0        NaN     NaN          93.0         NaN
# 2004      NaN     NaN      73.0        NaN     NaN          71.0         NaN
# 2008     82.0     NaN       NaN        NaN    86.0           NaN        93.0
# 2012      NaN    91.0       NaN       74.0    76.0           NaN        82.0
# 2016      NaN     NaN       NaN       71.0     NaN          88.0        90.0
# 2020     91.0     NaN      79.0        NaN     NaN           NaN         NaN
# 2024     96.0     NaN       NaN        NaN    75.0           NaN         NaN

# %%
print(miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 50])
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      91        74         24      59            93          16
# 2004       38      18        73         35      11            71          21
# 2016       53      13        65         71      57            88          90
# 2020       91      44        79         67      64            62          11

# %%
miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 80][['Vilnius', 'Klaipeda']]
# Out:
# Empty DataFrame
# Columns: [Vilnius, Klaipeda]
# Index: []

# %%
miestu_skaiciai[(miestu_skaiciai['Vilnius'] > 90) | (miestu_skaiciai['Klaipeda'] > 80)]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      91        74         24      59            93          16
# 2020       91      44        79         67      64            62          11
# 2024       96      21        12         70      75            18          21

# %%
miestu_skaiciai.reset_index()
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      91        74         24      59            93
# 1   2004       38      18        73         35      11            71
# 2   2008       82      48        39         32      86            59
# 3   2012       59      91        44         74      76            49
# 4   2016       53      13        65         71      57            88
# 5   2020       91      44        79         67      64            62
# 6   2024       96      21        12         70      75            18
#
#    Kazlu Ruda
# 0          16
# 1          21
# 2          93
# 3          82
# 4          90
# 5          11
# 6          21

# %%
be_indekso = miestu_skaiciai.reset_index()
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      91        74         24      59            93
# 1   2004       38      18        73         35      11            71
# 2   2008       82      48        39         32      86            59
# 3   2012       59      91        44         74      76            49
# 4   2016       53      13        65         71      57            88
# 5   2020       91      44        79         67      64            62
# 6   2024       96      21        12         70      75            18
#
#    Kazlu Ruda
# 0          16
# 1          21
# 2          93
# 3          82
# 4          90
# 5          11
# 6          21

# %%
be_indekso['Utena'] = np.random.randint(10, 71, 7)
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      91        74         24      59            93
# 1   2004       38      18        73         35      11            71
# 2   2008       82      48        39         32      86            59
# 3   2012       59      91        44         74      76            49
# 4   2016       53      13        65         71      57            88
# 5   2020       91      44        79         67      64            62
# 6   2024       96      21        12         70      75            18
#
#    Kazlu Ruda  Utena
# 0          16     68
# 1          21     34
# 2          93     64
# 3          82     56
# 4          90     46
# 5          11     53
# 6          21     16

# %%
su_utena = be_indekso.set_index('index')
su_utena
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99      91        74         24      59            93          16
# 2004        38      18        73         35      11            71          21
# 2008        82      48        39         32      86            59          93
# 2012        59      91        44         74      76            49          82
# 2016        53      13        65         71      57            88          90
# 2020        91      44        79         67      64            62          11
# 2024        96      21        12         70      75            18          21
#
#        Utena
# index
# 2000      68
# 2004      34
# 2008      64
# 2012      56
# 2016      46
# 2020      53
# 2024      16

# %% [markdown]
# ## antra dalis
# ---

# %% [markdown]
# fiktyviai sugadianm duomenis

# %%
su_nuostoliu = su_utena[su_utena > 20]
su_nuostoliu
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    91.0      74.0         24    59.0          93.0         NaN
# 2004        38     NaN      73.0         35     NaN          71.0        21.0
# 2008        82    48.0      39.0         32    86.0          59.0        93.0
# 2012        59    91.0      44.0         74    76.0          49.0        82.0
# 2016        53     NaN      65.0         71    57.0          88.0        90.0
# 2020        91    44.0      79.0         67    64.0          62.0         NaN
# 2024        96    21.0       NaN         70    75.0           NaN        21.0
#
#        Utena
# index
# 2000    68.0
# 2004    34.0
# 2008    64.0
# 2012    56.0
# 2016    46.0
# 2020    53.0
# 2024     NaN

# %% [markdown]
# tikrinam duomenų kokybę, kur jų trūksta

# %%
su_nuostoliu.isnull()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000     False   False     False      False   False         False        True
# 2004     False    True     False      False    True         False       False
# 2008     False   False     False      False   False         False       False
# 2012     False   False     False      False   False         False       False
# 2016     False    True     False      False   False         False       False
# 2020     False   False     False      False   False         False        True
# 2024     False   False      True      False   False          True       False
#
#        Utena
# index
# 2000   False
# 2004   False
# 2008   False
# 2012   False
# 2016   False
# 2020   False
# 2024    True

# %%
su_nuostoliu.isnull().sum()
# Out:
# Vilnius         0
# Kaunas          2
# Klaipeda        1
# Panevezys       0
# Alytus          1
# Druskininkai    1
# Kazlu Ruda      2
# Utena           1
# dtype: int64

# %%
su_nuostoliu['Klaipeda'].isnull()
# Out:
# index
# 2000    False
# 2004    False
# 2008    False
# 2012    False
# 2016    False
# 2020    False
# 2024     True
# Name: Klaipeda, dtype: bool

# %%
su_nuostoliu['Klaipeda'].isnull().sum()
# Out:
# 1

# %% [markdown]
# išmetam eilutes, kur duomenų trūksta

# %%
su_nuostoliu.dropna()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2008        82    48.0      39.0         32    86.0          59.0        93.0
# 2012        59    91.0      44.0         74    76.0          49.0        82.0
#
#        Utena
# index
# 2008    64.0
# 2012    56.0

# %% [markdown]
# išmetam stulpelius, kur duomenų trūksta

# %%
su_nuostoliu.dropna(axis=1)
# Out:
#        Vilnius  Panevezys
# index
# 2000        99         24
# 2004        38         35
# 2008        82         32
# 2012        59         74
# 2016        53         71
# 2020        91         67
# 2024        96         70

# %% [markdown]
# išmetam eilutes, kurių stulpelių duomenų kiekis neviršyja thresh

# %%
su_nuostoliu.dropna(thresh=7)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    91.0      74.0         24    59.0          93.0         NaN
# 2008        82    48.0      39.0         32    86.0          59.0        93.0
# 2012        59    91.0      44.0         74    76.0          49.0        82.0
# 2016        53     NaN      65.0         71    57.0          88.0        90.0
# 2020        91    44.0      79.0         67    64.0          62.0         NaN
#
#        Utena
# index
# 2000    68.0
# 2008    64.0
# 2012    56.0
# 2016    46.0
# 2020    53.0

# %% [markdown]
# išmetam stulpelius, kurių eilučių duomenų kiekis neviršyje thresh

# %%
su_nuostoliu.dropna(thresh=6, axis=1)
# Out:
#        Vilnius  Klaipeda  Panevezys  Alytus  Druskininkai  Utena
# index
# 2000        99      74.0         24    59.0          93.0   68.0
# 2004        38      73.0         35     NaN          71.0   34.0
# 2008        82      39.0         32    86.0          59.0   64.0
# 2012        59      44.0         74    76.0          49.0   56.0
# 2016        53      65.0         71    57.0          88.0   46.0
# 2020        91      79.0         67    64.0          62.0   53.0
# 2024        96       NaN         70    75.0           NaN    NaN

# %% [markdown]
# užpildom nesamus duomenis 'kiauras' reikšme

# %%
su_nuostoliu.fillna('kiauras')
# Out:
#        Vilnius   Kaunas Klaipeda  Panevezys   Alytus Druskininkai Kazlu Ruda  \
# index
# 2000        99     91.0     74.0         24     59.0         93.0    kiauras
# 2004        38  kiauras     73.0         35  kiauras         71.0       21.0
# 2008        82     48.0     39.0         32     86.0         59.0       93.0
# 2012        59     91.0     44.0         74     76.0         49.0       82.0
# 2016        53  kiauras     65.0         71     57.0         88.0       90.0
# 2020        91     44.0     79.0         67     64.0         62.0    kiauras
# 2024        96     21.0  kiauras         70     75.0      kiauras       21.0
#
#          Utena
# index
# 2000      68.0
# 2004      34.0
# 2008      64.0
# 2012      56.0
# 2016      46.0
# 2020      53.0
# 2024   kiauras

# %% [markdown]
# užpildome trūkstamus duomenis stulpelių vidurkiais

# %%
su_nuostoliu['Klaipeda'].fillna(value=su_nuostoliu['Klaipeda'].mean())
# Out:
# index
# 2000    74.000000
# 2004    73.000000
# 2008    39.000000
# 2012    44.000000
# 2016    65.000000
# 2020    79.000000
# 2024    62.333333
# Name: Klaipeda, dtype: float64

# %%
padengti_nuostoliai = su_nuostoliu.fillna(value=su_nuostoliu.mean())
np.round(padengti_nuostoliai, 2)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    91.0     74.00         24    59.0         93.00        61.4
# 2004        38    59.0     73.00         35    69.5         71.00        21.0
# 2008        82    48.0     39.00         32    86.0         59.00        93.0
# 2012        59    91.0     44.00         74    76.0         49.00        82.0
# 2016        53    59.0     65.00         71    57.0         88.00        90.0
# 2020        91    44.0     79.00         67    64.0         62.00        61.4
# 2024        96    21.0     62.33         70    75.0         70.33        21.0
#
#        Utena
# index
# 2000    68.0
# 2004    34.0
# 2008    64.0
# 2012    56.0
# 2016    46.0
# 2020    53.0
# 2024    53.5

# %% [markdown]
# ### grupavimas
#
# transponuojam lentelę, kad būtų patogiau dirbti su jos duomenimis

# %%
visi_miestai = su_utena.transpose()
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# Vilnius         99    38    82    59    53    91    96
# Kaunas          91    18    48    91    13    44    21
# Klaipeda        74    73    39    44    65    79    12
# Panevezys       24    35    32    74    71    67    70
# Alytus          59    11    86    76    57    64    75
# Druskininkai    93    71    59    49    88    62    18
# Kazlu Ruda      16    21    93    82    90    11    21
# Utena           68    34    64    56    46    53    16

# %% [markdown]
# pridedam regionus

# %%
regionai = pd.Series([
    'Miestas', 
    'Miestas', 
    'Mazoji Lietuva',
    'Aukstaitija', 
    'Dzukija', 
    'Dzukija', 
    'Mazoji Lietuva', 
    'Aukstaitija'
])
laikini = visi_miestai.reset_index()
laikini['regionai'] = regionai
visi_miestai = laikini.set_index('index')
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    38    82    59    53    91    96         Miestas
# Kaunas          91    18    48    91    13    44    21         Miestas
# Klaipeda        74    73    39    44    65    79    12  Mazoji Lietuva
# Panevezys       24    35    32    74    71    67    70     Aukstaitija
# Alytus          59    11    86    76    57    64    75         Dzukija
# Druskininkai    93    71    59    49    88    62    18         Dzukija
# Kazlu Ruda      16    21    93    82    90    11    21  Mazoji Lietuva
# Utena           68    34    64    56    46    53    16     Aukstaitija

# %% [markdown]
# sugrupuojam miestus pagal regionus, išvedam vidurkių lentelę

# %%
regionais = visi_miestai.groupby('regionai')
regionais.mean(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija     46.0  34.5  48.0  65.0  58.5  60.0  43.0
# Dzukija         76.0  41.0  72.5  62.5  72.5  63.0  46.5
# Mazoji Lietuva  45.0  47.0  66.0  63.0  77.5  45.0  16.5
# Miestas         95.0  28.0  65.0  75.0  33.0  67.5  58.5

# %% [markdown]
# regionų suma

# %%
regionais.sum(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       92    69    96   130   117   120    86
# Dzukija          152    82   145   125   145   126    93
# Mazoji Lietuva    90    94   132   126   155    90    33
# Miestas          190    56   130   150    66   135   117

# %% [markdown]
# regionų skaičius (realiai visų duomenų bus vienodas)

# %%
regionais.count()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija        2     2     2     2     2     2     2
# Dzukija            2     2     2     2     2     2     2
# Mazoji Lietuva     2     2     2     2     2     2     2
# Miestas            2     2     2     2     2     2     2

# %% [markdown]
# min/max

# %%
regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       24    34    32    56    46    53    16
# Dzukija           59    11    59    49    57    62    18
# Mazoji Lietuva    16    21    39    44    65    11    12
# Miestas           91    18    48    59    13    44    21

# %%
regionais.max() - regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       44     1    32    18    25    14    54
# Dzukija           34    60    27    27    31     2    57
# Mazoji Lietuva    58    52    54    38    25    68     9
# Miestas            8    20    34    32    40    47    75

# %% [markdown]
# statistinė analizė vieno stulpelio duomens

# %%
regionais[2024].describe()
# Out:
#                 count  mean        std   min    25%   50%    75%   max
# regionai
# Aukstaitija       2.0  43.0  38.183766  16.0  29.50  43.0  56.50  70.0
# Dzukija           2.0  46.5  40.305087  18.0  32.25  46.5  60.75  75.0
# Mazoji Lietuva    2.0  16.5   6.363961  12.0  14.25  16.5  18.75  21.0
# Miestas           2.0  58.5  53.033009  21.0  39.75  58.5  77.25  96.0

# %%
regionais[2024].describe().transpose()['Miestas']
# Out:
# count     2.000000
# mean     58.500000
# std      53.033009
# min      21.000000
# 25%      39.750000
# 50%      58.500000
# 75%      77.250000
# max      96.000000
# Name: Miestas, dtype: float64

# %% [markdown]
# ### DF jungimas

# %% [markdown]
# pasidalinam duomenis

# %%
iki_2010 = visi_miestai[['regionai', 2000, 2004, 2008]].copy()
po_2010 = visi_miestai[['regionai', 2012, 2016, 2020, 2024]].copy()

# %%
top4 = visi_miestai[:'Panevezys'].copy()
bottom4 = visi_miestai['Alytus':].copy()

# %%
pd.concat([top4, bottom4])
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    38    82    59    53    91    96         Miestas
# Kaunas          91    18    48    91    13    44    21         Miestas
# Klaipeda        74    73    39    44    65    79    12  Mazoji Lietuva
# Panevezys       24    35    32    74    71    67    70     Aukstaitija
# Alytus          59    11    86    76    57    64    75         Dzukija
# Druskininkai    93    71    59    49    88    62    18         Dzukija
# Kazlu Ruda      16    21    93    82    90    11    21  Mazoji Lietuva
# Utena           68    34    64    56    46    53    16     Aukstaitija

# %%
pd.concat([top4, bottom4], axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai  2000  \
# index
# Vilnius       99.0  38.0  82.0  59.0  53.0  91.0  96.0         Miestas   NaN
# Kaunas        91.0  18.0  48.0  91.0  13.0  44.0  21.0         Miestas   NaN
# Klaipeda      74.0  73.0  39.0  44.0  65.0  79.0  12.0  Mazoji Lietuva   NaN
# Panevezys     24.0  35.0  32.0  74.0  71.0  67.0  70.0     Aukstaitija   NaN
# Alytus         NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  59.0
# Druskininkai   NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  93.0
# Kazlu Ruda     NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  16.0
# Utena          NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  68.0
#
# index         2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius        NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Kaunas         NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Klaipeda       NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Panevezys      NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Alytus        11.0  86.0  76.0  57.0  64.0  75.0         Dzukija
# Druskininkai  71.0  59.0  49.0  88.0  62.0  18.0         Dzukija
# Kazlu Ruda    21.0  93.0  82.0  90.0  11.0  21.0  Mazoji Lietuva
# Utena         34.0  64.0  56.0  46.0  53.0  16.0     Aukstaitija

# %%
right4 = bottom4.reset_index()
right4.drop(columns='regionai', inplace=True)
right4
# Out:
# index         index  2000  2004  2008  2012  2016  2020  2024
# 0            Alytus    59    11    86    76    57    64    75
# 1      Druskininkai    93    71    59    49    88    62    18
# 2        Kazlu Ruda    16    21    93    82    90    11    21
# 3             Utena    68    34    64    56    46    53    16

# %%
left4 = top4.reset_index().drop(columns='regionai')
left4
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024
# 0        Vilnius    99    38    82    59    53    91    96
# 1         Kaunas    91    18    48    91    13    44    21
# 2       Klaipeda    74    73    39    44    65    79    12
# 3      Panevezys    24    35    32    74    71    67    70

# %%
pd.concat([left4, right4], axis=1)
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024         index  \
# 0        Vilnius    99    38    82    59    53    91    96        Alytus
# 1         Kaunas    91    18    48    91    13    44    21  Druskininkai
# 2       Klaipeda    74    73    39    44    65    79    12    Kazlu Ruda
# 3      Panevezys    24    35    32    74    71    67    70         Utena
#
# index  2000  2004  2008  2012  2016  2020  2024
# 0        59    11    86    76    57    64    75
# 1        93    71    59    49    88    62    18
# 2        16    21    93    82    90    11    21
# 3        68    34    64    56    46    53    16

# %%
pd.concat([iki_2010, po_2010], axis=1).drop(columns='regionai', axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius         99    38    82    59    53    91    96
# Kaunas          91    18    48    91    13    44    21
# Klaipeda        74    73    39    44    65    79    12
# Panevezys       24    35    32    74    71    67    70
# Alytus          59    11    86    76    57    64    75
# Druskininkai    93    71    59    49    88    62    18
# Kazlu Ruda      16    21    93    82    90    11    21
# Utena           68    34    64    56    46    53    16

# %%
pd.merge(iki_2010, po_2010, on=['index', 'regionai'])
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    38    82    59    53    91    96
# Kaunas               Miestas    91    18    48    91    13    44    21
# Klaipeda      Mazoji Lietuva    74    73    39    44    65    79    12
# Panevezys        Aukstaitija    24    35    32    74    71    67    70
# Alytus               Dzukija    59    11    86    76    57    64    75
# Druskininkai         Dzukija    93    71    59    49    88    62    18
# Kazlu Ruda    Mazoji Lietuva    16    21    93    82    90    11    21
# Utena            Aukstaitija    68    34    64    56    46    53    16

# %%
iki_2010.join(po_2010, lsuffix='', rsuffix=':R').drop(columns='regionai:R')
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    38    82    59    53    91    96
# Kaunas               Miestas    91    18    48    91    13    44    21
# Klaipeda      Mazoji Lietuva    74    73    39    44    65    79    12
# Panevezys        Aukstaitija    24    35    32    74    71    67    70
# Alytus               Dzukija    59    11    86    76    57    64    75
# Druskininkai         Dzukija    93    71    59    49    88    62    18
# Kazlu Ruda    Mazoji Lietuva    16    21    93    82    90    11    21
# Utena            Aukstaitija    68    34    64    56    46    53    16

# %% [markdown]
# ## trečia dalis
# ## Duomenų skaitymas/rašymas
# ---

# %%
top = pd.read_csv('top50.csv', encoding='ISO-8859-1')
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre
# 0           1                         Señorita   Shawn Mendes    canadian pop  \
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.
# 0               117      55            76              -6         8        75  \
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
top['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
top['Genre'].nunique()
# Out:
# 21

# %%
top['Genre'].value_counts()
# Out:
# Genre
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton           2
# reggaeton flow      2
# panamanian pop      2
# canadian pop        2
# electropop          2
# country rap         2
# dfw rap             2
# brostep             2
# trap music          1
# escape room         1
# pop house           1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: count, dtype: int64

# %%
top['Length.'].sum()
# Out:
# 10048

# %%
def minutes_seconds(length):
    return f"{length // 60}:{(length % 60):02d}"

# %%
top['Length.'].apply(minutes_seconds).head()
# Out:
# 0    3:11
# 1    5:02
# 2    3:06
# 3    3:18
# 4    2:55
# Name: Length., dtype: object

# %%
top['Length.Pretty'] = top['Length.'].apply(minutes_seconds)
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre
# 0           1                         Señorita   Shawn Mendes    canadian pop  \
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.
# 0               117      55            76              -6         8        75  \
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 0      191               4             3          79          3:11
# 1      302               8             9          92          5:02
# 2      186              12            46          85          3:06
# 3      198              12            19          86          3:18
# 4      175              45             7          94          2:55

# %%
top['Energy'].apply(lambda energy:energy // 10).head()
# Out:
# 0    5
# 1    8
# 2    8
# 3    6
# 4    6
# Name: Energy, dtype: int64

# %%
top.drop('Unnamed: 0', axis=1, inplace=True)

# %%
top.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity', 'Length.Pretty'],
#       dtype='object')

# %%
top.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
top.shape
# Out:
# (50, 14)

# %%
top.sort_values('Beats.Per.Minute', ascending=False).head()
# Out:
#                        Track.Name    Artist.Name           Genre
# 2   boyfriend (with Social House)  Ariana Grande       dance pop  \
# 6                          Ransom      Lil Tecca      trap music
# 10                       Callaita      Bad Bunny       reggaeton
# 36                     Otro Trago           Sech  panamanian pop
# 46                      Te Robaré      Nicky Jam           latin
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness
# 2                190      80            40              -4        16  \
# 6                180      64            75              -6         7
# 10               176      62            61              -5        24
# 36               176      70            75              -5        11
# 46               176      75            67              -4         8
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 2         70      186              12            46          85          3:06
# 6         23      131               2            29          92          2:11
# 10        24      251              60            31          93          4:11
# 36        62      226              14            34          91          3:46
# 46        80      202              24             6          88          3:22

# %%
top_speed = top.sort_values('Beats.Per.Minute', ascending=False)
top_speed.to_csv('top50_fastest.csv', index=True, index_label='Top.Index')

# %%
excel_writer = pd.ExcelWriter('top_speeed.xls', engine='xlsxwriter')
top_speed.to_excel(excel_writer, sheet_name='Fastest BPM')

# %% [markdown]
# ### HTML

# %%
html_data = pd.read_html('https://lt.wikipedia.org/wiki/Vilniaus_miesto_savivaldyb%C4%97')

# %%
seniunijos = html_data[5]
seniunijos.head()
# Out:
#                 Seniūnija Plotas km²  Gyventojai  (2023 m.)
# 0    Antakalnio seniūnija   77,2 km²                  43027  \
# 1  Fabijoniškių seniūnija   5,87 km²                  37360
# 2     Grigiškių seniūnija    7,1 km²                  10685
# 3   Justiniškių seniūnija   2,98 km²                  26263
# 4  Karoliniškių seniūnija    4,0 km²                  24643
#
#   Gyventojų tankumas km²  (2023 m.)
# 0                       557 žm./km²
# 1                      6365 žm./km²
# 2                      1505 žm./km²
# 3                      8813 žm./km²
# 4                      6161 žm./km²

# %%
from sqlalchemy import create_engine
db_engine = create_engine('sqlite:///db/seniunijos.db')

# %%
seniunijos.to_sql('seniunijos', con=db_engine, index=False)
# Out:
# 21

# %%
school_engine = create_engine('sqlite:///db/school/school.db')
schedule = pd.read_sql('schedule', con=school_engine)
schedule.head()
# Out:
#    id  weekday start_time  subject_id  classroom_id  teacher_id
# 0  41        0   08:00:00           1             1           1
# 1  42        0   13:00:00           2             1           2
# 2  43        1   08:00:00           1             1           1
# 3  44        1   13:00:00           3             1           3
# 4  45        2   08:00:00           1             1           1

# %%
query = '''SELECT weekday, start_time, subject.name, codename, teacher.last_name
FROM schedule
JOIN subject ON schedule.subject_id=subject.id
JOIN classroom ON schedule.classroom_id=classroom.id
JOIN teacher ON schedule.teacher_id=teacher.id;
'''
nice_schedule = pd.read_sql_query(query, con=school_engine)
nice_schedule
# Out:
#     weekday start_time        name codename  last_name
# 0         0   08:00:00      Python   code01  Petraitis
# 1         0   13:00:00  JavaScript   code01     Onaite
# 2         1   08:00:00      Python   code01  Petraitis
# 3         1   13:00:00    HTML/CSS   code01    Marijus
# 4         2   08:00:00      Python   code01  Petraitis
# 5         2   13:00:00  JavaScript   code01     Onaite
# 6         3   08:00:00      Python   code01  Petraitis
# 7         3   13:00:00    HTML/CSS   code01    Marijus
# 8         0   08:00:00      Python   code02    Rasaite
# 9         0   13:00:00    HTML/CSS   code02    Marijus
# 10        1   08:00:00      Python   code02    Rasaite
# 11        1   13:00:00  JavaScript   code02     Onaite
# 12        2   08:00:00      Python   code02    Rasaite
# 13        2   13:00:00    HTML/CSS   code02    Marijus
# 14        3   08:00:00      Python   code02    Rasaite
# 15        3   13:00:00  JavaScript   code02     Onaite
# 16        0   08:00:00  JavaScript   code03     Onaite
# 17        0   13:00:00      Python   code03  Petraitis
# 18        1   08:00:00    HTML/CSS   code03    Marijus
# 19        1   13:00:00      Python   code03  Petraitis
# 20        2   08:00:00  JavaScript   code03     Onaite
# 21        2   13:00:00      Python   code03  Petraitis
# 22        3   08:00:00    HTML/CSS   code03    Marijus
# 23        3   13:00:00      Python   code03  Petraitis
# 24        0   08:00:00    HTML/CSS   code04    Marijus
# 25        0   13:00:00      Python   code04    Rasaite
# 26        1   08:00:00  JavaScript   code04     Onaite
# 27        1   13:00:00      Python   code04    Rasaite
# 28        2   08:00:00    HTML/CSS   code04    Marijus
# 29        2   13:00:00      Python   code04    Rasaite
# 30        3   08:00:00  JavaScript   code04     Onaite
# 31        3   13:00:00      Python   code04    Rasaite
