# %%
import pandas as pd
import numpy as np
# Out:
# /var/folders/n6/nzyv9f853k7djbyfmdph5t5w0000gn/T/ipykernel_14090/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## pirma dalis
# ---

# %%
labels = ('vardas', 'pavardė', 'amžius')
zmogus = ('Geras', 'Zmogelis', 33)
print(labels, zmogus)
# Out:
# ('vardas', 'pavardė', 'amžius') ('Geras', 'Zmogelis', 33)

# %%
pd.Series(data=zmogus)
# Out:
# 0       Geras
# 1    Zmogelis
# 2          33
# dtype: object

# %%
pd.Series(data=zmogus, index=labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_dict = {
    'vardas': 'Smagus',
    'pavarde': 'Giedriukas',
    'amzius': 36
}
zmogus_dict
# Out:
# {'vardas': 'Smagus', 'pavarde': 'Giedriukas', 'amzius': 36}

# %%
zmogus_pd = pd.Series(zmogus_dict)
zmogus_pd
# Out:
# vardas         Smagus
# pavarde    Giedriukas
# amzius             36
# dtype: object

# %%
pd.Series(zmogus, labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_pd['amzius']
# Out:
# 36

# %%
miestai = pd.Series((500, 400, 300, 200), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
miestai
# Out:
# Vilnius     500
# Kaunas      400
# Klaipeda    300
# Siauliai    200
# dtype: int64

# %%
augimas = pd.Series((1.5, 1.3, 0.9, 0.7), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
augimas
# Out:
# Vilnius     1.5
# Kaunas      1.3
# Klaipeda    0.9
# Siauliai    0.7
# dtype: float64

# %%
miestai * augimas
# Out:
# Vilnius     750.0
# Kaunas      520.0
# Klaipeda    270.0
# Siauliai    140.0
# dtype: float64

# %%
betko7x7 = np.random.randint(10, 100, (7, 7))
betko7x7
# Out:
# array([[71, 95, 92, 33, 30, 79, 85],
#        [25, 70, 95, 89, 86, 48, 28],
#        [97, 67, 73, 43, 23, 95, 39],
#        [82, 56, 86, 22, 24, 84, 84],
#        [46, 89, 46, 40, 75, 32, 78],
#        [57, 69, 87, 62, 90, 77, 91],
#        [58, 15, 56, 80, 86, 64, 88]])

# %%
miestu_skaiciai = pd.DataFrame(
    betko7x7,
    [2000, 2004, 2008, 2012, 2016, 2020, 2024],
    ['Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai', 'Panevezys', 'Alytus', 'Druskininkai']
)
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai
# 2000       71      95        92        33         30      79            85
# 2004       25      70        95        89         86      48            28
# 2008       97      67        73        43         23      95            39
# 2012       82      56        86        22         24      84            84
# 2016       46      89        46        40         75      32            78
# 2020       57      69        87        62         90      77            91
# 2024       58      15        56        80         86      64            88

# %%
miestu_skaiciai['Klaipeda']
# Out:
# 2000    92
# 2004    95
# 2008    73
# 2012    86
# 2016    46
# 2020    87
# 2024    56
# Name: Klaipeda, dtype: int64

# %%
print(type(miestu_skaiciai['Klaipeda']))
print(type(miestu_skaiciai))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
miestu_skaiciai[['Vilnius', 'Alytus', 'Druskininkai']]
# Out:
#       Vilnius  Alytus  Druskininkai
# 2000       71      79            85
# 2004       25      48            28
# 2008       97      95            39
# 2012       82      84            84
# 2016       46      32            78
# 2020       57      77            91
# 2024       58      64            88

# %%
miestu_skaiciai['Vilnius'][2000] = 99
miestu_skaiciai['Vilnius'][2000]
# Out:
# /var/folders/n6/nzyv9f853k7djbyfmdph5t5w0000gn/T/ipykernel_14090/2762690240.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   miestu_skaiciai['Vilnius'][2000] = 99
# 99

# %%
miestu_skaiciai.loc[2012]
# Out:
# Vilnius         82
# Kaunas          56
# Klaipeda        86
# Siauliai        22
# Panevezys       24
# Alytus          84
# Druskininkai    84
# Name: 2012, dtype: int64

# %%
kazluruda = pd.Series(np.random.randint(10, 99, 7), np.arange(2000, 2025, 4))
kazluruda
# Out:
# 2000    70
# 2004    94
# 2008    56
# 2012    94
# 2016    96
# 2020    12
# 2024    16
# dtype: int64

# %%
miestu_skaiciai['Kazlu Ruda'] = kazluruda
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai  \
# 2000       99      95        92        33         30      79            85
# 2004       25      70        95        89         86      48            28
# 2008       97      67        73        43         23      95            39
# 2012       82      56        86        22         24      84            84
# 2016       46      89        46        40         75      32            78
# 2020       57      69        87        62         90      77            91
# 2024       58      15        56        80         86      64            88
#
#       Kazlu Ruda
# 2000          70
# 2004          94
# 2008          56
# 2012          94
# 2016          96
# 2020          12
# 2024          16

# %%
miestu_skaiciai.drop('Siauliai', axis=1, inplace=True)

# %%
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      95        92         30      79            85          70
# 2004       25      70        95         86      48            28          94
# 2008       97      67        73         23      95            39          56
# 2012       82      56        86         24      84            84          94
# 2016       46      89        46         75      32            78          96
# 2020       57      69        87         90      77            91          12
# 2024       58      15        56         86      64            88          16

# %%
miestai_be_2008 = miestu_skaiciai.drop(2008)
miestai_be_2008
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      95        92         30      79            85          70
# 2004       25      70        95         86      48            28          94
# 2012       82      56        86         24      84            84          94
# 2016       46      89        46         75      32            78          96
# 2020       57      69        87         90      77            91          12
# 2024       58      15        56         86      64            88          16

# %%
miestu_skaiciai.loc[2008]
# Out:
# Vilnius         97
# Kaunas          67
# Klaipeda        73
# Panevezys       23
# Alytus          95
# Druskininkai    39
# Kazlu Ruda      56
# Name: 2008, dtype: int64

# %%
miestu_skaiciai.iloc[3]
# Out:
# Vilnius         82
# Kaunas          56
# Klaipeda        86
# Panevezys       24
# Alytus          84
# Druskininkai    84
# Kazlu Ruda      94
# Name: 2012, dtype: int64

# %%
miestu_skaiciai['Vilnius'][2020]
# Out:
# 57

# %%
miestu_skaiciai.loc[2020, 'Vilnius']
# Out:
# 57

# %%
miestu_skaiciai.loc[[2012, 2020, 2024], ['Kaunas', 'Alytus']]
# Out:
#       Kaunas  Alytus
# 2012      56      84
# 2020      69      77
# 2024      15      64

# %%
miestu_skaiciai[['Kaunas', 'Alytus']].loc[[2020, 2012, 2000]]
# Out:
#       Kaunas  Alytus
# 2020      69      77
# 2012      56      84
# 2000      95      79

# %%
miestu_skaiciai[miestu_skaiciai > 70]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000     99.0    95.0      92.0        NaN    79.0          85.0         NaN
# 2004      NaN     NaN      95.0       86.0     NaN           NaN        94.0
# 2008     97.0     NaN      73.0        NaN    95.0           NaN         NaN
# 2012     82.0     NaN      86.0        NaN    84.0          84.0        94.0
# 2016      NaN    89.0       NaN       75.0     NaN          78.0        96.0
# 2020      NaN     NaN      87.0       90.0    77.0          91.0         NaN
# 2024      NaN     NaN       NaN       86.0     NaN          88.0         NaN

# %%
print(miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 50])
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      95        92         30      79            85          70
# 2004       25      70        95         86      48            28          94
# 2008       97      67        73         23      95            39          56
# 2012       82      56        86         24      84            84          94
# 2020       57      69        87         90      77            91          12
# 2024       58      15        56         86      64            88          16

# %%
miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 80][['Vilnius', 'Klaipeda']]
# Out:
#       Vilnius  Klaipeda
# 2000       99        92
# 2004       25        95
# 2012       82        86
# 2020       57        87

# %%
miestu_skaiciai[(miestu_skaiciai['Vilnius'] > 90) | (miestu_skaiciai['Klaipeda'] > 80)]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      95        92         30      79            85          70
# 2004       25      70        95         86      48            28          94
# 2008       97      67        73         23      95            39          56
# 2012       82      56        86         24      84            84          94
# 2020       57      69        87         90      77            91          12

# %%
miestu_skaiciai.reset_index()
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      95        92         30      79            85
# 1   2004       25      70        95         86      48            28
# 2   2008       97      67        73         23      95            39
# 3   2012       82      56        86         24      84            84
# 4   2016       46      89        46         75      32            78
# 5   2020       57      69        87         90      77            91
# 6   2024       58      15        56         86      64            88
#
#    Kazlu Ruda
# 0          70
# 1          94
# 2          56
# 3          94
# 4          96
# 5          12
# 6          16

# %%
be_indekso = miestu_skaiciai.reset_index()
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      95        92         30      79            85
# 1   2004       25      70        95         86      48            28
# 2   2008       97      67        73         23      95            39
# 3   2012       82      56        86         24      84            84
# 4   2016       46      89        46         75      32            78
# 5   2020       57      69        87         90      77            91
# 6   2024       58      15        56         86      64            88
#
#    Kazlu Ruda
# 0          70
# 1          94
# 2          56
# 3          94
# 4          96
# 5          12
# 6          16

# %%
be_indekso['Utena'] = np.random.randint(10, 71, 7)
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      95        92         30      79            85
# 1   2004       25      70        95         86      48            28
# 2   2008       97      67        73         23      95            39
# 3   2012       82      56        86         24      84            84
# 4   2016       46      89        46         75      32            78
# 5   2020       57      69        87         90      77            91
# 6   2024       58      15        56         86      64            88
#
#    Kazlu Ruda  Utena
# 0          70     65
# 1          94     36
# 2          56     45
# 3          94     21
# 4          96     70
# 5          12     21
# 6          16     41

# %%
su_utena = be_indekso.set_index('index')
su_utena
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99      95        92         30      79            85          70
# 2004        25      70        95         86      48            28          94
# 2008        97      67        73         23      95            39          56
# 2012        82      56        86         24      84            84          94
# 2016        46      89        46         75      32            78          96
# 2020        57      69        87         90      77            91          12
# 2024        58      15        56         86      64            88          16
#
#        Utena
# index
# 2000      65
# 2004      36
# 2008      45
# 2012      21
# 2016      70
# 2020      21
# 2024      41

# %% [markdown]
# ## antra dalis
# ---

# %% [markdown]
# fiktyviai sugadianm duomenis

# %%
su_nuostoliu = su_utena[su_utena > 20]
su_nuostoliu
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    95.0        92         30      79            85        70.0
# 2004        25    70.0        95         86      48            28        94.0
# 2008        97    67.0        73         23      95            39        56.0
# 2012        82    56.0        86         24      84            84        94.0
# 2016        46    89.0        46         75      32            78        96.0
# 2020        57    69.0        87         90      77            91         NaN
# 2024        58     NaN        56         86      64            88         NaN
#
#        Utena
# index
# 2000      65
# 2004      36
# 2008      45
# 2012      21
# 2016      70
# 2020      21
# 2024      41

# %% [markdown]
# tikrinam duomenų kokybę, kur jų trūksta

# %%
su_nuostoliu.isnull()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000     False   False     False      False   False         False       False
# 2004     False   False     False      False   False         False       False
# 2008     False   False     False      False   False         False       False
# 2012     False   False     False      False   False         False       False
# 2016     False   False     False      False   False         False       False
# 2020     False   False     False      False   False         False        True
# 2024     False    True     False      False   False         False        True
#
#        Utena
# index
# 2000   False
# 2004   False
# 2008   False
# 2012   False
# 2016   False
# 2020   False
# 2024   False

# %%
su_nuostoliu.isnull().sum()
# Out:
# Vilnius         0
# Kaunas          1
# Klaipeda        0
# Panevezys       0
# Alytus          0
# Druskininkai    0
# Kazlu Ruda      2
# Utena           0
# dtype: int64

# %%
su_nuostoliu['Klaipeda'].isnull()
# Out:
# index
# 2000    False
# 2004    False
# 2008    False
# 2012    False
# 2016    False
# 2020    False
# 2024    False
# Name: Klaipeda, dtype: bool

# %%
su_nuostoliu['Klaipeda'].isnull().sum()
# Out:
# 0

# %% [markdown]
# išmetam eilutes, kur duomenų trūksta

# %%
su_nuostoliu.dropna()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    95.0        92         30      79            85        70.0
# 2004        25    70.0        95         86      48            28        94.0
# 2008        97    67.0        73         23      95            39        56.0
# 2012        82    56.0        86         24      84            84        94.0
# 2016        46    89.0        46         75      32            78        96.0
#
#        Utena
# index
# 2000      65
# 2004      36
# 2008      45
# 2012      21
# 2016      70

# %% [markdown]
# išmetam stulpelius, kur duomenų trūksta

# %%
su_nuostoliu.dropna(axis=1)
# Out:
#        Vilnius  Klaipeda  Panevezys  Alytus  Druskininkai  Utena
# index
# 2000        99        92         30      79            85     65
# 2004        25        95         86      48            28     36
# 2008        97        73         23      95            39     45
# 2012        82        86         24      84            84     21
# 2016        46        46         75      32            78     70
# 2020        57        87         90      77            91     21
# 2024        58        56         86      64            88     41

# %% [markdown]
# išmetam eilutes, kurių stulpelių duomenų kiekis neviršyja thresh

# %%
su_nuostoliu.dropna(thresh=7)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    95.0        92         30      79            85        70.0
# 2004        25    70.0        95         86      48            28        94.0
# 2008        97    67.0        73         23      95            39        56.0
# 2012        82    56.0        86         24      84            84        94.0
# 2016        46    89.0        46         75      32            78        96.0
# 2020        57    69.0        87         90      77            91         NaN
#
#        Utena
# index
# 2000      65
# 2004      36
# 2008      45
# 2012      21
# 2016      70
# 2020      21

# %% [markdown]
# išmetam stulpelius, kurių eilučių duomenų kiekis neviršyje thresh

# %%
su_nuostoliu.dropna(thresh=6, axis=1)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Utena
# index
# 2000        99    95.0        92         30      79            85     65
# 2004        25    70.0        95         86      48            28     36
# 2008        97    67.0        73         23      95            39     45
# 2012        82    56.0        86         24      84            84     21
# 2016        46    89.0        46         75      32            78     70
# 2020        57    69.0        87         90      77            91     21
# 2024        58     NaN        56         86      64            88     41

# %% [markdown]
# užpildom nesamus duomenis 'kiauras' reikšme

# %%
su_nuostoliu.fillna('kiauras')
# Out:
#        Vilnius   Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai Kazlu Ruda  \
# index
# 2000        99     95.0        92         30      79            85       70.0
# 2004        25     70.0        95         86      48            28       94.0
# 2008        97     67.0        73         23      95            39       56.0
# 2012        82     56.0        86         24      84            84       94.0
# 2016        46     89.0        46         75      32            78       96.0
# 2020        57     69.0        87         90      77            91    kiauras
# 2024        58  kiauras        56         86      64            88    kiauras
#
#        Utena
# index
# 2000      65
# 2004      36
# 2008      45
# 2012      21
# 2016      70
# 2020      21
# 2024      41

# %% [markdown]
# užpildome trūkstamus duomenis stulpelių vidurkiais

# %%
su_nuostoliu['Klaipeda'].fillna(value=su_nuostoliu['Klaipeda'].mean())
# Out:
# index
# 2000    92
# 2004    95
# 2008    73
# 2012    86
# 2016    46
# 2020    87
# 2024    56
# Name: Klaipeda, dtype: int64

# %%
padengti_nuostoliai = su_nuostoliu.fillna(value=su_nuostoliu.mean())
np.round(padengti_nuostoliai, 2)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99   95.00        92         30      79            85        70.0
# 2004        25   70.00        95         86      48            28        94.0
# 2008        97   67.00        73         23      95            39        56.0
# 2012        82   56.00        86         24      84            84        94.0
# 2016        46   89.00        46         75      32            78        96.0
# 2020        57   69.00        87         90      77            91        82.0
# 2024        58   74.33        56         86      64            88        82.0
#
#        Utena
# index
# 2000      65
# 2004      36
# 2008      45
# 2012      21
# 2016      70
# 2020      21
# 2024      41

# %% [markdown]
# ### grupavimas
#
# transponuojam lentelę, kad būtų patogiau dirbti su jos duomenimis

# %%
visi_miestai = su_utena.transpose()
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# Vilnius         99    25    97    82    46    57    58
# Kaunas          95    70    67    56    89    69    15
# Klaipeda        92    95    73    86    46    87    56
# Panevezys       30    86    23    24    75    90    86
# Alytus          79    48    95    84    32    77    64
# Druskininkai    85    28    39    84    78    91    88
# Kazlu Ruda      70    94    56    94    96    12    16
# Utena           65    36    45    21    70    21    41

# %% [markdown]
# pridedam regionus

# %%
regionai = pd.Series([
    'Miestas', 
    'Miestas', 
    'Mazoji Lietuva',
    'Aukstaitija', 
    'Dzukija', 
    'Dzukija', 
    'Mazoji Lietuva', 
    'Aukstaitija'
])
laikini = visi_miestai.reset_index()
laikini['regionai'] = regionai
visi_miestai = laikini.set_index('index')
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    25    97    82    46    57    58         Miestas
# Kaunas          95    70    67    56    89    69    15         Miestas
# Klaipeda        92    95    73    86    46    87    56  Mazoji Lietuva
# Panevezys       30    86    23    24    75    90    86     Aukstaitija
# Alytus          79    48    95    84    32    77    64         Dzukija
# Druskininkai    85    28    39    84    78    91    88         Dzukija
# Kazlu Ruda      70    94    56    94    96    12    16  Mazoji Lietuva
# Utena           65    36    45    21    70    21    41     Aukstaitija

# %% [markdown]
# sugrupuojam miestus pagal regionus, išvedam vidurkių lentelę

# %%
regionais = visi_miestai.groupby('regionai')
regionais.mean(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija     47.5  61.0  34.0  22.5  72.5  55.5  63.5
# Dzukija         82.0  38.0  67.0  84.0  55.0  84.0  76.0
# Mazoji Lietuva  81.0  94.5  64.5  90.0  71.0  49.5  36.0
# Miestas         97.0  47.5  82.0  69.0  67.5  63.0  36.5

# %% [markdown]
# regionų suma

# %%
regionais.sum(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       95   122    68    45   145   111   127
# Dzukija          164    76   134   168   110   168   152
# Mazoji Lietuva   162   189   129   180   142    99    72
# Miestas          194    95   164   138   135   126    73

# %% [markdown]
# regionų skaičius (realiai visų duomenų bus vienodas)

# %%
regionais.count()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija        2     2     2     2     2     2     2
# Dzukija            2     2     2     2     2     2     2
# Mazoji Lietuva     2     2     2     2     2     2     2
# Miestas            2     2     2     2     2     2     2

# %% [markdown]
# min/max

# %%
regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       30    36    23    21    70    21    41
# Dzukija           79    28    39    84    32    77    64
# Mazoji Lietuva    70    94    56    86    46    12    16
# Miestas           95    25    67    56    46    57    15

# %%
regionais.max() - regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       35    50    22     3     5    69    45
# Dzukija            6    20    56     0    46    14    24
# Mazoji Lietuva    22     1    17     8    50    75    40
# Miestas            4    45    30    26    43    12    43

# %% [markdown]
# statistinė analizė vieno stulpelio duomens

# %%
regionais[2024].describe()
# Out:
#                 count  mean        std   min    25%   50%    75%   max
# regionai
# Aukstaitija       2.0  63.5  31.819805  41.0  52.25  63.5  74.75  86.0
# Dzukija           2.0  76.0  16.970563  64.0  70.00  76.0  82.00  88.0
# Mazoji Lietuva    2.0  36.0  28.284271  16.0  26.00  36.0  46.00  56.0
# Miestas           2.0  36.5  30.405592  15.0  25.75  36.5  47.25  58.0

# %%
regionais[2024].describe().transpose()['Miestas']
# Out:
# count     2.000000
# mean     36.500000
# std      30.405592
# min      15.000000
# 25%      25.750000
# 50%      36.500000
# 75%      47.250000
# max      58.000000
# Name: Miestas, dtype: float64

# %% [markdown]
# ### DF jungimas

# %% [markdown]
# pasidalinam duomenis

# %%
iki_2010 = visi_miestai[['regionai', 2000, 2004, 2008]].copy()
po_2010 = visi_miestai[['regionai', 2012, 2016, 2020, 2024]].copy()

# %%
top4 = visi_miestai[:'Panevezys'].copy()
bottom4 = visi_miestai['Alytus':].copy()

# %%
pd.concat([top4, bottom4])
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    25    97    82    46    57    58         Miestas
# Kaunas          95    70    67    56    89    69    15         Miestas
# Klaipeda        92    95    73    86    46    87    56  Mazoji Lietuva
# Panevezys       30    86    23    24    75    90    86     Aukstaitija
# Alytus          79    48    95    84    32    77    64         Dzukija
# Druskininkai    85    28    39    84    78    91    88         Dzukija
# Kazlu Ruda      70    94    56    94    96    12    16  Mazoji Lietuva
# Utena           65    36    45    21    70    21    41     Aukstaitija

# %%
pd.concat([top4, bottom4], axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai  2000  \
# index
# Vilnius       99.0  25.0  97.0  82.0  46.0  57.0  58.0         Miestas   NaN
# Kaunas        95.0  70.0  67.0  56.0  89.0  69.0  15.0         Miestas   NaN
# Klaipeda      92.0  95.0  73.0  86.0  46.0  87.0  56.0  Mazoji Lietuva   NaN
# Panevezys     30.0  86.0  23.0  24.0  75.0  90.0  86.0     Aukstaitija   NaN
# Alytus         NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  79.0
# Druskininkai   NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  85.0
# Kazlu Ruda     NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  70.0
# Utena          NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  65.0
#
# index         2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius        NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Kaunas         NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Klaipeda       NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Panevezys      NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Alytus        48.0  95.0  84.0  32.0  77.0  64.0         Dzukija
# Druskininkai  28.0  39.0  84.0  78.0  91.0  88.0         Dzukija
# Kazlu Ruda    94.0  56.0  94.0  96.0  12.0  16.0  Mazoji Lietuva
# Utena         36.0  45.0  21.0  70.0  21.0  41.0     Aukstaitija

# %%
right4 = bottom4.reset_index()
right4.drop(columns='regionai', inplace=True)
right4
# Out:
# index         index  2000  2004  2008  2012  2016  2020  2024
# 0            Alytus    79    48    95    84    32    77    64
# 1      Druskininkai    85    28    39    84    78    91    88
# 2        Kazlu Ruda    70    94    56    94    96    12    16
# 3             Utena    65    36    45    21    70    21    41

# %%
left4 = top4.reset_index().drop(columns='regionai')
left4
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024
# 0        Vilnius    99    25    97    82    46    57    58
# 1         Kaunas    95    70    67    56    89    69    15
# 2       Klaipeda    92    95    73    86    46    87    56
# 3      Panevezys    30    86    23    24    75    90    86

# %%
pd.concat([left4, right4], axis=1)
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024         index  \
# 0        Vilnius    99    25    97    82    46    57    58        Alytus
# 1         Kaunas    95    70    67    56    89    69    15  Druskininkai
# 2       Klaipeda    92    95    73    86    46    87    56    Kazlu Ruda
# 3      Panevezys    30    86    23    24    75    90    86         Utena
#
# index  2000  2004  2008  2012  2016  2020  2024
# 0        79    48    95    84    32    77    64
# 1        85    28    39    84    78    91    88
# 2        70    94    56    94    96    12    16
# 3        65    36    45    21    70    21    41

# %%
pd.concat([iki_2010, po_2010], axis=1).drop(columns='regionai', axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius         99    25    97    82    46    57    58
# Kaunas          95    70    67    56    89    69    15
# Klaipeda        92    95    73    86    46    87    56
# Panevezys       30    86    23    24    75    90    86
# Alytus          79    48    95    84    32    77    64
# Druskininkai    85    28    39    84    78    91    88
# Kazlu Ruda      70    94    56    94    96    12    16
# Utena           65    36    45    21    70    21    41

# %%
pd.merge(iki_2010, po_2010, on=['index', 'regionai'])
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    25    97    82    46    57    58
# Kaunas               Miestas    95    70    67    56    89    69    15
# Klaipeda      Mazoji Lietuva    92    95    73    86    46    87    56
# Panevezys        Aukstaitija    30    86    23    24    75    90    86
# Alytus               Dzukija    79    48    95    84    32    77    64
# Druskininkai         Dzukija    85    28    39    84    78    91    88
# Kazlu Ruda    Mazoji Lietuva    70    94    56    94    96    12    16
# Utena            Aukstaitija    65    36    45    21    70    21    41

# %%
iki_2010.join(po_2010, lsuffix='', rsuffix=':R').drop(columns='regionai:R')
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    25    97    82    46    57    58
# Kaunas               Miestas    95    70    67    56    89    69    15
# Klaipeda      Mazoji Lietuva    92    95    73    86    46    87    56
# Panevezys        Aukstaitija    30    86    23    24    75    90    86
# Alytus               Dzukija    79    48    95    84    32    77    64
# Druskininkai         Dzukija    85    28    39    84    78    91    88
# Kazlu Ruda    Mazoji Lietuva    70    94    56    94    96    12    16
# Utena            Aukstaitija    65    36    45    21    70    21    41

# %% [markdown]
# ## trečia dalis
# ## Duomenų skaitymas/rašymas
# ---

# %%
top = pd.read_csv('top50.csv', encoding='ISO-8859-1')
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
top['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
top['Genre'].nunique()
# Out:
# 21

# %%
top['Genre'].value_counts()
# Out:
# Genre
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# dfw rap             2
# reggaeton flow      2
# canadian pop        2
# country rap         2
# panamanian pop      2
# reggaeton           2
# brostep             2
# electropop          2
# escape room         1
# trap music          1
# australian pop      1
# pop house           1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: count, dtype: int64

# %%
top['Length.'].sum()
# Out:
# 10048

# %%
def minutes_seconds(length):
    return f"{length // 60}:{(length % 60):02d}"

# %%
top['Length.'].apply(minutes_seconds).head()
# Out:
# 0    3:11
# 1    5:02
# 2    3:06
# 3    3:18
# 4    2:55
# Name: Length., dtype: object

# %%
top['Length.Pretty'] = top['Length.'].apply(minutes_seconds)
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 0      191               4             3          79          3:11
# 1      302               8             9          92          5:02
# 2      186              12            46          85          3:06
# 3      198              12            19          86          3:18
# 4      175              45             7          94          2:55

# %%
top['Energy'].apply(lambda energy:energy // 10).head()
# Out:
# 0    5
# 1    8
# 2    8
# 3    6
# 4    6
# Name: Energy, dtype: int64

# %%
top.drop('Unnamed: 0', axis=1, inplace=True)

# %%
top.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity', 'Length.Pretty'],
#       dtype='object')

# %%
top.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
top.shape
# Out:
# (50, 14)

# %%
top.sort_values('Beats.Per.Minute', ascending=False).head()
# Out:
#                        Track.Name    Artist.Name           Genre  \
# 2   boyfriend (with Social House)  Ariana Grande       dance pop
# 6                          Ransom      Lil Tecca      trap music
# 16                     LA CANCIÓN       J Balvin           latin
# 10                       Callaita      Bad Bunny       reggaeton
# 13             Otro Trago - Remix           Sech  panamanian pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 2                190      80            40              -4        16
# 6                180      64            75              -6         7
# 16               176      65            75              -6        11
# 10               176      62            61              -5        24
# 13               176      79            73              -2         6
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 2         70      186              12            46          85          3:06
# 6         23      131               2            29          92          2:11
# 16        43      243              15            32          90          4:03
# 10        24      251              60            31          93          4:11
# 13        76      288               7            20          87          4:48

# %%
top_speed = top.sort_values('Beats.Per.Minute', ascending=False)
top_speed.to_csv('top50_fastest.csv', index=True, index_label='Top.Index')

# %%
excel_writer = pd.ExcelWriter('top_speeed.xls', engine='xlsxwriter')
top_speed.to_excel(excel_writer, sheet_name='Fastest BPM')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 excel_writer = pd.ExcelWriter('top_speeed.xls', engine='xlsxwriter')
#       2 top_speed.to_excel(excel_writer, sheet_name='Fastest BPM')
#
# File ~/Documents/CodeAcademy/course-python-basic/venv/lib/python3.11/site-packages/pandas/io/excel/_xlsxwriter.py:197, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     184 def __init__(
#     185     self,
#     186     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#     195 ) -> None:
#     196     # Use the xlsxwriter module as the Excel writer.
# --> 197     from xlsxwriter import Workbook
#     199     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#     201     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %% [markdown]
# ### HTML

# %%
html_data = pd.read_html('https://lt.wikipedia.org/wiki/Vilniaus_miesto_savivaldyb%C4%97')

# %%
seniunijos = html_data[5]
seniunijos.head()
# Out:
#                 Seniūnija Plotas km²  Gyventojai  (2023 m.)
# 0    Antakalnio seniūnija   77,2 km²                  43027  \
# 1  Fabijoniškių seniūnija   5,87 km²                  37360
# 2     Grigiškių seniūnija    7,1 km²                  10685
# 3   Justiniškių seniūnija   2,98 km²                  26263
# 4  Karoliniškių seniūnija    4,0 km²                  24643
#
#   Gyventojų tankumas km²  (2023 m.)
# 0                       557 žm./km²
# 1                      6365 žm./km²
# 2                      1505 žm./km²
# 3                      8813 žm./km²
# 4                      6161 žm./km²

# %%
from sqlalchemy import create_engine
db_engine = create_engine('sqlite:///db/seniunijos.db')

# %%
seniunijos.to_sql('seniunijos', con=db_engine, index=False)
# Out:
# 21

# %%
school_engine = create_engine('sqlite:///db/school/school.db')
schedule = pd.read_sql('schedule', con=school_engine)
schedule.head()
# Out:
#    id  weekday start_time  subject_id  classroom_id  teacher_id
# 0  41        0   08:00:00           1             1           1
# 1  42        0   13:00:00           2             1           2
# 2  43        1   08:00:00           1             1           1
# 3  44        1   13:00:00           3             1           3
# 4  45        2   08:00:00           1             1           1

# %%
query = '''SELECT weekday, start_time, subject.name, codename, teacher.last_name
FROM schedule
JOIN subject ON schedule.subject_id=subject.id
JOIN classroom ON schedule.classroom_id=classroom.id
JOIN teacher ON schedule.teacher_id=teacher.id;
'''
nice_schedule = pd.read_sql_query(query, con=school_engine)
nice_schedule
# Out:
#     weekday start_time        name codename  last_name
# 0         0   08:00:00      Python   code01  Petraitis
# 1         0   13:00:00  JavaScript   code01     Onaite
# 2         1   08:00:00      Python   code01  Petraitis
# 3         1   13:00:00    HTML/CSS   code01    Marijus
# 4         2   08:00:00      Python   code01  Petraitis
# 5         2   13:00:00  JavaScript   code01     Onaite
# 6         3   08:00:00      Python   code01  Petraitis
# 7         3   13:00:00    HTML/CSS   code01    Marijus
# 8         0   08:00:00      Python   code02    Rasaite
# 9         0   13:00:00    HTML/CSS   code02    Marijus
# 10        1   08:00:00      Python   code02    Rasaite
# 11        1   13:00:00  JavaScript   code02     Onaite
# 12        2   08:00:00      Python   code02    Rasaite
# 13        2   13:00:00    HTML/CSS   code02    Marijus
# 14        3   08:00:00      Python   code02    Rasaite
# 15        3   13:00:00  JavaScript   code02     Onaite
# 16        0   08:00:00  JavaScript   code03     Onaite
# 17        0   13:00:00      Python   code03  Petraitis
# 18        1   08:00:00    HTML/CSS   code03    Marijus
# 19        1   13:00:00      Python   code03  Petraitis
# 20        2   08:00:00  JavaScript   code03     Onaite
# 21        2   13:00:00      Python   code03  Petraitis
# 22        3   08:00:00    HTML/CSS   code03    Marijus
# 23        3   13:00:00      Python   code03  Petraitis
# 24        0   08:00:00    HTML/CSS   code04    Marijus
# 25        0   13:00:00      Python   code04    Rasaite
# 26        1   08:00:00  JavaScript   code04     Onaite
# 27        1   13:00:00      Python   code04    Rasaite
# 28        2   08:00:00    HTML/CSS   code04    Marijus
# 29        2   13:00:00      Python   code04    Rasaite
# 30        3   08:00:00  JavaScript   code04     Onaite
# 31        3   13:00:00      Python   code04    Rasaite
