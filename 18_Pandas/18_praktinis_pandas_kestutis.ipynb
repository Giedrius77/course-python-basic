# %%
import pandas as pd
import numpy as np
# Out:
# /var/folders/n6/nzyv9f853k7djbyfmdph5t5w0000gn/T/ipykernel_20665/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## pirma dalis
# ---

# %%
labels = ('vardas', 'pavardė', 'amžius')
zmogus = ('Geras', 'Zmogelis', 33)
print(labels, zmogus)
# Out:
# ('vardas', 'pavardė', 'amžius') ('Geras', 'Zmogelis', 33)

# %%
pd.Series(data=zmogus)
# Out:
# 0       Geras
# 1    Zmogelis
# 2          33
# dtype: object

# %%
pd.Series(data=zmogus, index=labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_dict = {
    'vardas': 'Smagus',
    'pavarde': 'Giedriukas',
    'amzius': 36
}
zmogus_dict
# Out:
# {'vardas': 'Smagus', 'pavarde': 'Giedriukas', 'amzius': 36}

# %%
zmogus_pd = pd.Series(zmogus_dict)
zmogus_pd
# Out:
# vardas         Smagus
# pavarde    Giedriukas
# amzius             36
# dtype: object

# %%
pd.Series(zmogus, labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_pd['amzius']
# Out:
# 36

# %%
miestai = pd.Series((500, 400, 300, 200), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
miestai
# Out:
# Vilnius     500
# Kaunas      400
# Klaipeda    300
# Siauliai    200
# dtype: int64

# %%
augimas = pd.Series((1.5, 1.3, 0.9, 0.7), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
augimas
# Out:
# Vilnius     1.5
# Kaunas      1.3
# Klaipeda    0.9
# Siauliai    0.7
# dtype: float64

# %%
miestai * augimas
# Out:
# Vilnius     750.0
# Kaunas      520.0
# Klaipeda    270.0
# Siauliai    140.0
# dtype: float64

# %%
betko7x7 = np.random.randint(10, 100, (7, 7))
betko7x7
# Out:
# array([[15, 13, 81, 62, 81, 79, 71],
#        [11, 67, 69, 51, 82, 54, 62],
#        [23, 17, 19, 58, 73, 71, 84],
#        [68, 64, 32, 52, 37, 49, 52],
#        [25, 36, 78, 43, 58, 71, 28],
#        [62, 34, 28, 81, 34, 48, 28],
#        [69, 23, 95, 43, 41, 96, 16]])

# %%
miestu_skaiciai = pd.DataFrame(
    betko7x7,
    [2000, 2004, 2008, 2012, 2016, 2020, 2024],
    ['Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai', 'Panevezys', 'Alytus', 'Druskininkai']
)
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai
# 2000       15      13        81        62         81      79            71
# 2004       11      67        69        51         82      54            62
# 2008       23      17        19        58         73      71            84
# 2012       68      64        32        52         37      49            52
# 2016       25      36        78        43         58      71            28
# 2020       62      34        28        81         34      48            28
# 2024       69      23        95        43         41      96            16

# %%
miestu_skaiciai['Klaipeda']
# Out:
# 2000    81
# 2004    69
# 2008    19
# 2012    32
# 2016    78
# 2020    28
# 2024    95
# Name: Klaipeda, dtype: int64

# %%
print(type(miestu_skaiciai['Klaipeda']))
print(type(miestu_skaiciai))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
miestu_skaiciai[['Vilnius', 'Alytus', 'Druskininkai']]
# Out:
#       Vilnius  Alytus  Druskininkai
# 2000       15      79            71
# 2004       11      54            62
# 2008       23      71            84
# 2012       68      49            52
# 2016       25      71            28
# 2020       62      48            28
# 2024       69      96            16

# %%
miestu_skaiciai['Vilnius'][2000] = 99
miestu_skaiciai['Vilnius'][2000]
# Out:
# /var/folders/n6/nzyv9f853k7djbyfmdph5t5w0000gn/T/ipykernel_20665/2762690240.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   miestu_skaiciai['Vilnius'][2000] = 99
# 99

# %%
miestu_skaiciai.loc[2012]
# Out:
# Vilnius         68
# Kaunas          64
# Klaipeda        32
# Siauliai        52
# Panevezys       37
# Alytus          49
# Druskininkai    52
# Name: 2012, dtype: int64

# %%
kazluruda = pd.Series(np.random.randint(10, 99, 7), np.arange(2000, 2025, 4))
kazluruda
# Out:
# 2000    80
# 2004    64
# 2008    85
# 2012    10
# 2016    87
# 2020    81
# 2024    60
# dtype: int64

# %%
miestu_skaiciai['Kazlu Ruda'] = kazluruda
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai  \
# 2000       99      13        81        62         81      79            71
# 2004       11      67        69        51         82      54            62
# 2008       23      17        19        58         73      71            84
# 2012       68      64        32        52         37      49            52
# 2016       25      36        78        43         58      71            28
# 2020       62      34        28        81         34      48            28
# 2024       69      23        95        43         41      96            16
#
#       Kazlu Ruda
# 2000          80
# 2004          64
# 2008          85
# 2012          10
# 2016          87
# 2020          81
# 2024          60

# %%
miestu_skaiciai.drop('Siauliai', axis=1, inplace=True)

# %%
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      13        81         81      79            71          80
# 2004       11      67        69         82      54            62          64
# 2008       23      17        19         73      71            84          85
# 2012       68      64        32         37      49            52          10
# 2016       25      36        78         58      71            28          87
# 2020       62      34        28         34      48            28          81
# 2024       69      23        95         41      96            16          60

# %%
miestai_be_2008 = miestu_skaiciai.drop(2008)
miestai_be_2008
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      13        81         81      79            71          80
# 2004       11      67        69         82      54            62          64
# 2012       68      64        32         37      49            52          10
# 2016       25      36        78         58      71            28          87
# 2020       62      34        28         34      48            28          81
# 2024       69      23        95         41      96            16          60

# %%
miestu_skaiciai.loc[2008]
# Out:
# Vilnius         23
# Kaunas          17
# Klaipeda        19
# Panevezys       73
# Alytus          71
# Druskininkai    84
# Kazlu Ruda      85
# Name: 2008, dtype: int64

# %%
miestu_skaiciai.iloc[3]
# Out:
# Vilnius         68
# Kaunas          64
# Klaipeda        32
# Panevezys       37
# Alytus          49
# Druskininkai    52
# Kazlu Ruda      10
# Name: 2012, dtype: int64

# %%
miestu_skaiciai['Vilnius'][2020]
# Out:
# 62

# %%
miestu_skaiciai.loc[2020, 'Vilnius']
# Out:
# 62

# %%
miestu_skaiciai.loc[[2012, 2020, 2024], ['Kaunas', 'Alytus']]
# Out:
#       Kaunas  Alytus
# 2012      64      49
# 2020      34      48
# 2024      23      96

# %%
miestu_skaiciai[['Kaunas', 'Alytus']].loc[[2020, 2012, 2000]]
# Out:
#       Kaunas  Alytus
# 2020      34      48
# 2012      64      49
# 2000      13      79

# %%
miestu_skaiciai[miestu_skaiciai > 70]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000     99.0     NaN      81.0       81.0    79.0          71.0        80.0
# 2004      NaN     NaN       NaN       82.0     NaN           NaN         NaN
# 2008      NaN     NaN       NaN       73.0    71.0          84.0        85.0
# 2012      NaN     NaN       NaN        NaN     NaN           NaN         NaN
# 2016      NaN     NaN      78.0        NaN    71.0           NaN        87.0
# 2020      NaN     NaN       NaN        NaN     NaN           NaN        81.0
# 2024      NaN     NaN      95.0        NaN    96.0           NaN         NaN

# %%
print(miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 50])
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      13        81         81      79            71          80
# 2004       11      67        69         82      54            62          64
# 2016       25      36        78         58      71            28          87
# 2024       69      23        95         41      96            16          60

# %%
miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 80][['Vilnius', 'Klaipeda']]
# Out:
#       Vilnius  Klaipeda
# 2000       99        81
# 2024       69        95

# %%
miestu_skaiciai[(miestu_skaiciai['Vilnius'] > 90) | (miestu_skaiciai['Klaipeda'] > 80)]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      13        81         81      79            71          80
# 2024       69      23        95         41      96            16          60

# %%
miestu_skaiciai.reset_index()
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      13        81         81      79            71
# 1   2004       11      67        69         82      54            62
# 2   2008       23      17        19         73      71            84
# 3   2012       68      64        32         37      49            52
# 4   2016       25      36        78         58      71            28
# 5   2020       62      34        28         34      48            28
# 6   2024       69      23        95         41      96            16
#
#    Kazlu Ruda
# 0          80
# 1          64
# 2          85
# 3          10
# 4          87
# 5          81
# 6          60

# %%
be_indekso = miestu_skaiciai.reset_index()
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      13        81         81      79            71
# 1   2004       11      67        69         82      54            62
# 2   2008       23      17        19         73      71            84
# 3   2012       68      64        32         37      49            52
# 4   2016       25      36        78         58      71            28
# 5   2020       62      34        28         34      48            28
# 6   2024       69      23        95         41      96            16
#
#    Kazlu Ruda
# 0          80
# 1          64
# 2          85
# 3          10
# 4          87
# 5          81
# 6          60

# %%
be_indekso['Utena'] = np.random.randint(10, 71, 7)
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      13        81         81      79            71
# 1   2004       11      67        69         82      54            62
# 2   2008       23      17        19         73      71            84
# 3   2012       68      64        32         37      49            52
# 4   2016       25      36        78         58      71            28
# 5   2020       62      34        28         34      48            28
# 6   2024       69      23        95         41      96            16
#
#    Kazlu Ruda  Utena
# 0          80     22
# 1          64     66
# 2          85     35
# 3          10     39
# 4          87     37
# 5          81     28
# 6          60     28

# %%
su_utena = be_indekso.set_index('index')
su_utena
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99      13        81         81      79            71          80
# 2004        11      67        69         82      54            62          64
# 2008        23      17        19         73      71            84          85
# 2012        68      64        32         37      49            52          10
# 2016        25      36        78         58      71            28          87
# 2020        62      34        28         34      48            28          81
# 2024        69      23        95         41      96            16          60
#
#        Utena
# index
# 2000      22
# 2004      66
# 2008      35
# 2012      39
# 2016      37
# 2020      28
# 2024      28

# %% [markdown]
# ## antra dalis
# ---

# %% [markdown]
# fiktyviai sugadianm duomenis

# %%
su_nuostoliu = su_utena[su_utena > 20]
su_nuostoliu
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000      99.0     NaN      81.0         81      79          71.0        80.0
# 2004       NaN    67.0      69.0         82      54          62.0        64.0
# 2008      23.0     NaN       NaN         73      71          84.0        85.0
# 2012      68.0    64.0      32.0         37      49          52.0         NaN
# 2016      25.0    36.0      78.0         58      71          28.0        87.0
# 2020      62.0    34.0      28.0         34      48          28.0        81.0
# 2024      69.0    23.0      95.0         41      96           NaN        60.0
#
#        Utena
# index
# 2000      22
# 2004      66
# 2008      35
# 2012      39
# 2016      37
# 2020      28
# 2024      28

# %% [markdown]
# tikrinam duomenų kokybę, kur jų trūksta

# %%
su_nuostoliu.isnull()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000     False    True     False      False   False         False       False
# 2004      True   False     False      False   False         False       False
# 2008     False    True      True      False   False         False       False
# 2012     False   False     False      False   False         False        True
# 2016     False   False     False      False   False         False       False
# 2020     False   False     False      False   False         False       False
# 2024     False   False     False      False   False          True       False
#
#        Utena
# index
# 2000   False
# 2004   False
# 2008   False
# 2012   False
# 2016   False
# 2020   False
# 2024   False

# %%
su_nuostoliu.isnull().sum()
# Out:
# Vilnius         1
# Kaunas          2
# Klaipeda        1
# Panevezys       0
# Alytus          0
# Druskininkai    1
# Kazlu Ruda      1
# Utena           0
# dtype: int64

# %%
su_nuostoliu['Klaipeda'].isnull()
# Out:
# index
# 2000    False
# 2004    False
# 2008     True
# 2012    False
# 2016    False
# 2020    False
# 2024    False
# Name: Klaipeda, dtype: bool

# %%
su_nuostoliu['Klaipeda'].isnull().sum()
# Out:
# 1

# %% [markdown]
# išmetam eilutes, kur duomenų trūksta

# %%
su_nuostoliu.dropna()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2016      25.0    36.0      78.0         58      71          28.0        87.0
# 2020      62.0    34.0      28.0         34      48          28.0        81.0
#
#        Utena
# index
# 2016      37
# 2020      28

# %% [markdown]
# išmetam stulpelius, kur duomenų trūksta

# %%
su_nuostoliu.dropna(axis=1)
# Out:
#        Panevezys  Alytus  Utena
# index
# 2000          81      79     22
# 2004          82      54     66
# 2008          73      71     35
# 2012          37      49     39
# 2016          58      71     37
# 2020          34      48     28
# 2024          41      96     28

# %% [markdown]
# išmetam eilutes, kurių stulpelių duomenų kiekis neviršyja thresh

# %%
su_nuostoliu.dropna(thresh=7)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000      99.0     NaN      81.0         81      79          71.0        80.0
# 2004       NaN    67.0      69.0         82      54          62.0        64.0
# 2012      68.0    64.0      32.0         37      49          52.0         NaN
# 2016      25.0    36.0      78.0         58      71          28.0        87.0
# 2020      62.0    34.0      28.0         34      48          28.0        81.0
# 2024      69.0    23.0      95.0         41      96           NaN        60.0
#
#        Utena
# index
# 2000      22
# 2004      66
# 2012      39
# 2016      37
# 2020      28
# 2024      28

# %% [markdown]
# išmetam stulpelius, kurių eilučių duomenų kiekis neviršyje thresh

# %%
su_nuostoliu.dropna(thresh=6, axis=1)
# Out:
#        Vilnius  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  Utena
# index
# 2000      99.0      81.0         81      79          71.0        80.0     22
# 2004       NaN      69.0         82      54          62.0        64.0     66
# 2008      23.0       NaN         73      71          84.0        85.0     35
# 2012      68.0      32.0         37      49          52.0         NaN     39
# 2016      25.0      78.0         58      71          28.0        87.0     37
# 2020      62.0      28.0         34      48          28.0        81.0     28
# 2024      69.0      95.0         41      96           NaN        60.0     28

# %% [markdown]
# užpildom nesamus duomenis 'kiauras' reikšme

# %%
su_nuostoliu.fillna('kiauras')
# Out:
#        Vilnius   Kaunas Klaipeda  Panevezys  Alytus Druskininkai Kazlu Ruda  \
# index
# 2000      99.0  kiauras     81.0         81      79         71.0       80.0
# 2004   kiauras     67.0     69.0         82      54         62.0       64.0
# 2008      23.0  kiauras  kiauras         73      71         84.0       85.0
# 2012      68.0     64.0     32.0         37      49         52.0    kiauras
# 2016      25.0     36.0     78.0         58      71         28.0       87.0
# 2020      62.0     34.0     28.0         34      48         28.0       81.0
# 2024      69.0     23.0     95.0         41      96      kiauras       60.0
#
#        Utena
# index
# 2000      22
# 2004      66
# 2008      35
# 2012      39
# 2016      37
# 2020      28
# 2024      28

# %% [markdown]
# užpildome trūkstamus duomenis stulpelių vidurkiais

# %%
su_nuostoliu['Klaipeda'].fillna(value=su_nuostoliu['Klaipeda'].mean())
# Out:
# index
# 2000    81.000000
# 2004    69.000000
# 2008    63.833333
# 2012    32.000000
# 2016    78.000000
# 2020    28.000000
# 2024    95.000000
# Name: Klaipeda, dtype: float64

# %%
padengti_nuostoliai = su_nuostoliu.fillna(value=su_nuostoliu.mean())
np.round(padengti_nuostoliai, 2)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000     99.00    44.8     81.00         81      79         71.00       80.00
# 2004     57.67    67.0     69.00         82      54         62.00       64.00
# 2008     23.00    44.8     63.83         73      71         84.00       85.00
# 2012     68.00    64.0     32.00         37      49         52.00       76.17
# 2016     25.00    36.0     78.00         58      71         28.00       87.00
# 2020     62.00    34.0     28.00         34      48         28.00       81.00
# 2024     69.00    23.0     95.00         41      96         54.17       60.00
#
#        Utena
# index
# 2000      22
# 2004      66
# 2008      35
# 2012      39
# 2016      37
# 2020      28
# 2024      28

# %% [markdown]
# ### grupavimas
#
# transponuojam lentelę, kad būtų patogiau dirbti su jos duomenimis

# %%
visi_miestai = su_utena.transpose()
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# Vilnius         99    11    23    68    25    62    69
# Kaunas          13    67    17    64    36    34    23
# Klaipeda        81    69    19    32    78    28    95
# Panevezys       81    82    73    37    58    34    41
# Alytus          79    54    71    49    71    48    96
# Druskininkai    71    62    84    52    28    28    16
# Kazlu Ruda      80    64    85    10    87    81    60
# Utena           22    66    35    39    37    28    28

# %% [markdown]
# pridedam regionus

# %%
regionai = pd.Series([
    'Miestas', 
    'Miestas', 
    'Mazoji Lietuva',
    'Aukstaitija', 
    'Dzukija', 
    'Dzukija', 
    'Mazoji Lietuva', 
    'Aukstaitija'
])
laikini = visi_miestai.reset_index()
laikini['regionai'] = regionai
visi_miestai = laikini.set_index('index')
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    11    23    68    25    62    69         Miestas
# Kaunas          13    67    17    64    36    34    23         Miestas
# Klaipeda        81    69    19    32    78    28    95  Mazoji Lietuva
# Panevezys       81    82    73    37    58    34    41     Aukstaitija
# Alytus          79    54    71    49    71    48    96         Dzukija
# Druskininkai    71    62    84    52    28    28    16         Dzukija
# Kazlu Ruda      80    64    85    10    87    81    60  Mazoji Lietuva
# Utena           22    66    35    39    37    28    28     Aukstaitija

# %% [markdown]
# sugrupuojam miestus pagal regionus, išvedam vidurkių lentelę

# %%
regionais = visi_miestai.groupby('regionai')
regionais.mean(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija     51.5  74.0  54.0  38.0  47.5  31.0  34.5
# Dzukija         75.0  58.0  77.5  50.5  49.5  38.0  56.0
# Mazoji Lietuva  80.5  66.5  52.0  21.0  82.5  54.5  77.5
# Miestas         56.0  39.0  20.0  66.0  30.5  48.0  46.0

# %% [markdown]
# regionų suma

# %%
regionais.sum(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija      103   148   108    76    95    62    69
# Dzukija          150   116   155   101    99    76   112
# Mazoji Lietuva   161   133   104    42   165   109   155
# Miestas          112    78    40   132    61    96    92

# %% [markdown]
# regionų skaičius (realiai visų duomenų bus vienodas)

# %%
regionais.count()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija        2     2     2     2     2     2     2
# Dzukija            2     2     2     2     2     2     2
# Mazoji Lietuva     2     2     2     2     2     2     2
# Miestas            2     2     2     2     2     2     2

# %% [markdown]
# min/max

# %%
regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       22    66    35    37    37    28    28
# Dzukija           71    54    71    49    28    28    16
# Mazoji Lietuva    80    64    19    10    78    28    60
# Miestas           13    11    17    64    25    34    23

# %%
regionais.max() - regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       59    16    38     2    21     6    13
# Dzukija            8     8    13     3    43    20    80
# Mazoji Lietuva     1     5    66    22     9    53    35
# Miestas           86    56     6     4    11    28    46

# %% [markdown]
# statistinė analizė vieno stulpelio duomens

# %%
regionais[2024].describe()
# Out:
#                 count  mean        std   min    25%   50%    75%   max
# regionai
# Aukstaitija       2.0  34.5   9.192388  28.0  31.25  34.5  37.75  41.0
# Dzukija           2.0  56.0  56.568542  16.0  36.00  56.0  76.00  96.0
# Mazoji Lietuva    2.0  77.5  24.748737  60.0  68.75  77.5  86.25  95.0
# Miestas           2.0  46.0  32.526912  23.0  34.50  46.0  57.50  69.0

# %%
regionais[2024].describe().transpose()['Miestas']
# Out:
# count     2.000000
# mean     46.000000
# std      32.526912
# min      23.000000
# 25%      34.500000
# 50%      46.000000
# 75%      57.500000
# max      69.000000
# Name: Miestas, dtype: float64

# %% [markdown]
# ### DF jungimas

# %% [markdown]
# pasidalinam duomenis

# %%
iki_2010 = visi_miestai[['regionai', 2000, 2004, 2008]].copy()
po_2010 = visi_miestai[['regionai', 2012, 2016, 2020, 2024]].copy()

# %%
top4 = visi_miestai[:'Panevezys'].copy()
bottom4 = visi_miestai['Alytus':].copy()

# %%
pd.concat([top4, bottom4])
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    11    23    68    25    62    69         Miestas
# Kaunas          13    67    17    64    36    34    23         Miestas
# Klaipeda        81    69    19    32    78    28    95  Mazoji Lietuva
# Panevezys       81    82    73    37    58    34    41     Aukstaitija
# Alytus          79    54    71    49    71    48    96         Dzukija
# Druskininkai    71    62    84    52    28    28    16         Dzukija
# Kazlu Ruda      80    64    85    10    87    81    60  Mazoji Lietuva
# Utena           22    66    35    39    37    28    28     Aukstaitija

# %%
pd.concat([top4, bottom4], axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai  2000  \
# index
# Vilnius       99.0  11.0  23.0  68.0  25.0  62.0  69.0         Miestas   NaN
# Kaunas        13.0  67.0  17.0  64.0  36.0  34.0  23.0         Miestas   NaN
# Klaipeda      81.0  69.0  19.0  32.0  78.0  28.0  95.0  Mazoji Lietuva   NaN
# Panevezys     81.0  82.0  73.0  37.0  58.0  34.0  41.0     Aukstaitija   NaN
# Alytus         NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  79.0
# Druskininkai   NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  71.0
# Kazlu Ruda     NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  80.0
# Utena          NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  22.0
#
# index         2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius        NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Kaunas         NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Klaipeda       NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Panevezys      NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Alytus        54.0  71.0  49.0  71.0  48.0  96.0         Dzukija
# Druskininkai  62.0  84.0  52.0  28.0  28.0  16.0         Dzukija
# Kazlu Ruda    64.0  85.0  10.0  87.0  81.0  60.0  Mazoji Lietuva
# Utena         66.0  35.0  39.0  37.0  28.0  28.0     Aukstaitija

# %%
right4 = bottom4.reset_index()
right4.drop(columns='regionai', inplace=True)
right4
# Out:
# index         index  2000  2004  2008  2012  2016  2020  2024
# 0            Alytus    79    54    71    49    71    48    96
# 1      Druskininkai    71    62    84    52    28    28    16
# 2        Kazlu Ruda    80    64    85    10    87    81    60
# 3             Utena    22    66    35    39    37    28    28

# %%
left4 = top4.reset_index().drop(columns='regionai')
left4
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024
# 0        Vilnius    99    11    23    68    25    62    69
# 1         Kaunas    13    67    17    64    36    34    23
# 2       Klaipeda    81    69    19    32    78    28    95
# 3      Panevezys    81    82    73    37    58    34    41

# %%
pd.concat([left4, right4], axis=1)
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024         index  \
# 0        Vilnius    99    11    23    68    25    62    69        Alytus
# 1         Kaunas    13    67    17    64    36    34    23  Druskininkai
# 2       Klaipeda    81    69    19    32    78    28    95    Kazlu Ruda
# 3      Panevezys    81    82    73    37    58    34    41         Utena
#
# index  2000  2004  2008  2012  2016  2020  2024
# 0        79    54    71    49    71    48    96
# 1        71    62    84    52    28    28    16
# 2        80    64    85    10    87    81    60
# 3        22    66    35    39    37    28    28

# %%
pd.concat([iki_2010, po_2010], axis=1).drop(columns='regionai', axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius         99    11    23    68    25    62    69
# Kaunas          13    67    17    64    36    34    23
# Klaipeda        81    69    19    32    78    28    95
# Panevezys       81    82    73    37    58    34    41
# Alytus          79    54    71    49    71    48    96
# Druskininkai    71    62    84    52    28    28    16
# Kazlu Ruda      80    64    85    10    87    81    60
# Utena           22    66    35    39    37    28    28

# %%
pd.merge(iki_2010, po_2010, on=['index', 'regionai'])
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    11    23    68    25    62    69
# Kaunas               Miestas    13    67    17    64    36    34    23
# Klaipeda      Mazoji Lietuva    81    69    19    32    78    28    95
# Panevezys        Aukstaitija    81    82    73    37    58    34    41
# Alytus               Dzukija    79    54    71    49    71    48    96
# Druskininkai         Dzukija    71    62    84    52    28    28    16
# Kazlu Ruda    Mazoji Lietuva    80    64    85    10    87    81    60
# Utena            Aukstaitija    22    66    35    39    37    28    28

# %%
iki_2010.join(po_2010, lsuffix='', rsuffix=':R').drop(columns='regionai:R')
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    11    23    68    25    62    69
# Kaunas               Miestas    13    67    17    64    36    34    23
# Klaipeda      Mazoji Lietuva    81    69    19    32    78    28    95
# Panevezys        Aukstaitija    81    82    73    37    58    34    41
# Alytus               Dzukija    79    54    71    49    71    48    96
# Druskininkai         Dzukija    71    62    84    52    28    28    16
# Kazlu Ruda    Mazoji Lietuva    80    64    85    10    87    81    60
# Utena            Aukstaitija    22    66    35    39    37    28    28

# %% [markdown]
# ## trečia dalis
# ## Duomenų skaitymas/rašymas
# ---

# %%
top = pd.read_csv('top50.csv', encoding='ISO-8859-1')
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
top['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
top['Genre'].nunique()
# Out:
# 21

# %%
top['Genre'].value_counts()
# Out:
# Genre
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# dfw rap             2
# reggaeton flow      2
# canadian pop        2
# country rap         2
# panamanian pop      2
# reggaeton           2
# brostep             2
# electropop          2
# escape room         1
# trap music          1
# australian pop      1
# pop house           1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: count, dtype: int64

# %%
top['Length.'].sum()
# Out:
# 10048

# %%
def minutes_seconds(length):
    return f"{length // 60}:{(length % 60):02d}"

# %%
top['Length.'].apply(minutes_seconds).head()
# Out:
# 0    3:11
# 1    5:02
# 2    3:06
# 3    3:18
# 4    2:55
# Name: Length., dtype: object

# %%
top['Length.Pretty'] = top['Length.'].apply(minutes_seconds)
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 0      191               4             3          79          3:11
# 1      302               8             9          92          5:02
# 2      186              12            46          85          3:06
# 3      198              12            19          86          3:18
# 4      175              45             7          94          2:55

# %%
top['Energy'].apply(lambda energy:energy // 10).head()
# Out:
# 0    5
# 1    8
# 2    8
# 3    6
# 4    6
# Name: Energy, dtype: int64

# %%
top.drop('Unnamed: 0', axis=1, inplace=True)

# %%
top.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity', 'Length.Pretty'],
#       dtype='object')

# %%
top.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
top.shape
# Out:
# (50, 14)

# %%
top.sort_values('Beats.Per.Minute', ascending=False).head()
# Out:
#                        Track.Name    Artist.Name           Genre  \
# 2   boyfriend (with Social House)  Ariana Grande       dance pop
# 6                          Ransom      Lil Tecca      trap music
# 16                     LA CANCIÓN       J Balvin           latin
# 10                       Callaita      Bad Bunny       reggaeton
# 13             Otro Trago - Remix           Sech  panamanian pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 2                190      80            40              -4        16
# 6                180      64            75              -6         7
# 16               176      65            75              -6        11
# 10               176      62            61              -5        24
# 13               176      79            73              -2         6
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 2         70      186              12            46          85          3:06
# 6         23      131               2            29          92          2:11
# 16        43      243              15            32          90          4:03
# 10        24      251              60            31          93          4:11
# 13        76      288               7            20          87          4:48

# %%
top_speed = top.sort_values('Beats.Per.Minute', ascending=False)
top_speed.to_csv('top50_fastest.csv', index=True, index_label='Top.Index')

# %%
excel_writer = pd.ExcelWriter('top_speeed.xls', engine='xlsxwriter')
top_speed.to_excel(excel_writer, sheet_name='Fastest BPM')

# %% [markdown]
# ### HTML

# %%
html_data = pd.read_html('https://lt.wikipedia.org/wiki/Vilniaus_miesto_savivaldyb%C4%97')

# %%
seniunijos = html_data[5]
seniunijos.head()
# Out:
#                 Seniūnija Plotas km²  Gyventojai  (2023 m.)  \
# 0    Antakalnio seniūnija   77,2 km²                  43027
# 1  Fabijoniškių seniūnija   5,87 km²                  37360
# 2     Grigiškių seniūnija    7,1 km²                  10685
# 3   Justiniškių seniūnija   2,98 km²                  26263
# 4  Karoliniškių seniūnija    4,0 km²                  24643
#
#   Gyventojų tankumas km²  (2023 m.)
# 0                       557 žm./km²
# 1                      6365 žm./km²
# 2                      1505 žm./km²
# 3                      8813 žm./km²
# 4                      6161 žm./km²

# %%
from sqlalchemy import create_engine
db_engine = create_engine('sqlite:///db/seniunijos.db')

# %%
seniunijos.to_sql('seniunijos', con=db_engine, index=False)

# %%
school_engine = create_engine('sqlite:///db/school/school.db')
schedule = pd.read_sql('schedule', con=school_engine)
schedule.head()
# Out:
#    id  weekday start_time  subject_id  classroom_id  teacher_id
# 0  41        0   08:00:00           1             1           1
# 1  42        0   13:00:00           2             1           2
# 2  43        1   08:00:00           1             1           1
# 3  44        1   13:00:00           3             1           3
# 4  45        2   08:00:00           1             1           1

# %%
query = '''SELECT weekday, start_time, subject.name, codename, teacher.last_name
FROM schedule
JOIN subject ON schedule.subject_id=subject.id
JOIN classroom ON schedule.classroom_id=classroom.id
JOIN teacher ON schedule.teacher_id=teacher.id;
'''
nice_schedule = pd.read_sql_query(query, con=school_engine)
nice_schedule
# Out:
#     weekday start_time        name codename  last_name
# 0         0   08:00:00      Python   code01  Petraitis
# 1         0   13:00:00  JavaScript   code01     Onaite
# 2         1   08:00:00      Python   code01  Petraitis
# 3         1   13:00:00    HTML/CSS   code01    Marijus
# 4         2   08:00:00      Python   code01  Petraitis
# 5         2   13:00:00  JavaScript   code01     Onaite
# 6         3   08:00:00      Python   code01  Petraitis
# 7         3   13:00:00    HTML/CSS   code01    Marijus
# 8         0   08:00:00      Python   code02    Rasaite
# 9         0   13:00:00    HTML/CSS   code02    Marijus
# 10        1   08:00:00      Python   code02    Rasaite
# 11        1   13:00:00  JavaScript   code02     Onaite
# 12        2   08:00:00      Python   code02    Rasaite
# 13        2   13:00:00    HTML/CSS   code02    Marijus
# 14        3   08:00:00      Python   code02    Rasaite
# 15        3   13:00:00  JavaScript   code02     Onaite
# 16        0   08:00:00  JavaScript   code03     Onaite
# 17        0   13:00:00      Python   code03  Petraitis
# 18        1   08:00:00    HTML/CSS   code03    Marijus
# 19        1   13:00:00      Python   code03  Petraitis
# 20        2   08:00:00  JavaScript   code03     Onaite
# 21        2   13:00:00      Python   code03  Petraitis
# 22        3   08:00:00    HTML/CSS   code03    Marijus
# 23        3   13:00:00      Python   code03  Petraitis
# 24        0   08:00:00    HTML/CSS   code04    Marijus
# 25        0   13:00:00      Python   code04    Rasaite
# 26        1   08:00:00  JavaScript   code04     Onaite
# 27        1   13:00:00      Python   code04    Rasaite
# 28        2   08:00:00    HTML/CSS   code04    Marijus
# 29        2   13:00:00      Python   code04    Rasaite
# 30        3   08:00:00  JavaScript   code04     Onaite
# 31        3   13:00:00      Python   code04    Rasaite
